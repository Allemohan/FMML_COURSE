# %% [markdown]
# <a href="https://colab.research.google.com/github/Allemohan/FMML_COURSE/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 15:44:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   140MB/s    in 0.5s
#
# 2024-03-26 15:44:34 (140 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19930   1303.5419v1  The trajectory of a robot is monitored in a re...    cs
# 7603   1802.04687v1  Interacting systems are prevalent in nature, f...  stat
# 22093   1411.0707v1  We use statistical learning methods to constru...  stat
# 10242  1803.05752v1  Rearranging objects on a tabletop surface by m...    cs
# 32400  1612.00554v1  Feature selection is a process of choosing a s...    cs
# ...             ...                                                ...   ...
# 7413   1712.06260v1  Accurate diagnosis of psychiatric disorders pl...  stat
# 1389   1605.09507v3  Identifying musical instruments in polyphonic ...    cs
# 4298   1801.03523v1  The present paper aims to demonstrate the usag...  stat
# 25400  1508.04843v1  Efforts to automate the reconstruction of neur...    cs
# 13298   0802.0251v1  In some real world situations, linear models a...    cs
#
#                                                    title  year  \
# 19930    Sensor Validation Using Dynamic Belief Networks  2013
# 7603   Neural Relational Inference for Interacting Sy...  2018
# 22093  A Nonparametric Adaptive Nonlinear Statistical...  2014
# 10242  Rearrangement with Nonprehensile Manipulation ...  2018
# 32400  Higher Order Mutual Information Approximation ...  2016
# ...                                                  ...   ...
# 7413   Deep Neural Generative Model of Functional MRI...  2017
# 1389   Deep convolutional neural networks for predomi...  2016
# 4298   Generative Models for Stochastic Processes Usi...  2018
# 25400  Recursive Training of 2D-3D Convolutional Netw...  2015
# 13298          Multi-Layer Perceptrons and Symbolic Data  2008
#
#                                                 keywords
# 19930  [trajectory, monitored, restricted, environmen...
# 7603   [interacting, prevalent, dynamical, interplay,...
# 22093  [statistical, construct, estimator, nonlinear,...
# 10242  [rearranging, nonprehensile, manipulation, int...
# 32400  [selection, prediction, extensive, information...
# ...                                                  ...
# 7413   [diagnosis, psychiatric, disorders, improving,...
# 1389   [identifying, instruments, polyphonic, recordi...
# 4298   [demonstrate, convolutional, generative, stoch...
# 25400  [reconstruction, microscopic, connectomics, im...
# 13298  [situations, sufficient, represent, accurately...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19930    [trajectory, monitored, restricted, environmen...
# 7603     [interacting, prevalent, dynamical, interplay,...
# 22093    [statistical, construct, estimator, nonlinear,...
# 10242    [rearranging, nonprehensile, manipulation, int...
# 32400    [selection, prediction, extensive, information...
#                                ...
# 7370     [arbitrary, differentiable, elementary, follow...
# 8501     [approximate, multimedia, retrieval, computati...
# 35539    [disjunctive, admitting, computational, proper...
# 21030    [complexity, theorists, structural, parameters...
# 24775    [estimation, monocular, challenging, available...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8799 words.
# Out of those 4600 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="29c2d3f7-ea5e-4f92-9454-56b86466e421" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29c2d3f7-ea5e-4f92-9454-56b86466e421")) {                    Plotly.newPlot(                        "29c2d3f7-ea5e-4f92-9454-56b86466e421",                        [{"x":["conventional","inconsistent","observations","quantitative","validation","extension","monitored","qualitative","monitoring","techniques","restricted","environment","impossible","connection","intermittent","instances","combination","persistent","partially","explanation","analogous","trajectory","successive","incorrect","interactions","reconstruction","simultaneously","explained","simulated","interacting","unsupervised","prevalent","represents","experiments","components","inference","dynamical","interplay","structure","accurately","underlying","constituent","relational","observational","interaction","interpretable","demonstrate","variational","introduce","estimates","nonparametric","estimated","estimation","stochastic","described","manuscript","nonlinear","distribution","constructed","accordingly","jackknife","uncertainty","estimator","statistical","assumptions","measurement","knowledge","uncertainties","construct","collisions","experience","reinforcement","properties","exploration","simulation","manipulation","suboptimal","heuristic","potential","precisely","explicitly","performance","empirical","theoretic","approximation","interdependent","collection","computational","summation","information","extensive","selection","technique","entropies","selections","maximizes","complexity","maximizing","approaches","comprehension","combinations","prediction","producing","automating","successes","suggested","correlation","manifestations","supervised","dependence","supervision","representations","translated","characterized","principle","redundancy","ambiguous","multivariate","including","converges","strategies","classifiers","convergence","differentiable","quadrature","expectation","algorithm","deterministic","combining","propagation","numerical","implicitly","computationally","substantially","inefficient","directions","hyperparameter","algorithms","available","practical","computation","inception","successfully","additional","resources","effectiveness","furthermore","diminishing","optimizer","alternatively","optimization","baselines","processes","graphical","preferable","previously","marginalization","applicable","precision","independent","attracted","approximations","rejection","continuous","intuitive","literature","combinatorics","approximate","comparably","determinantal","evaluation","relevance","important","generalized","revisited","undecidable","sensitive","constraint","languages","definition","simplifying","processed","condition","foundation","transducer","generative","phonology","extensions","derivations","hypotheses","equivalent","implemented","investigations","connections","sequential","nonmonotonic","populations","clustering","interested","individuals"],"y":[115,11,74,75,51,78,2,54,38,392,44,111,20,40,5,101,144,5,46,23,13,28,7,10,69,110,111,14,62,15,145,7,54,608,105,208,22,11,343,73,131,4,32,11,68,33,579,49,330,65,28,47,201,125,77,4,61,192,60,20,0,87,25,143,68,25,379,11,86,5,50,116,216,59,75,15,10,64,181,32,81,878,141,48,93,5,83,286,5,703,190,157,231,1,2,13,228,19,427,20,36,213,28,6,16,25,79,1,213,25,60,251,20,32,53,15,18,20,244,31,90,106,100,24,1,30,770,47,96,66,83,33,84,35,20,43,13,604,286,133,137,12,83,127,59,210,153,2,2,9,325,55,119,54,8,101,3,54,77,122,25,22,11,109,27,122,1,114,9,4,261,29,334,75,5,8,63,90,98,43,5,31,44,18,2,126,2,35,8,24,62,93,7,53,65,15,15,151,36,34],"type":"bar"},{"x":["conventional","inconsistent","observations","quantitative","validation","extensi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4600,), (4600, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8275

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fusion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>Hyperspectral</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Panchromatic</span> <span style=''>Images</span> <span style=''>using</span> <span style=''>Spectral</span> <span style=''>Uumixing</span> <span style=''>Results</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>Hyperspectral</span> <span style=''>imaging</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>high</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.6028368794326242);'>resolution</span> <span style=''>images</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>tools</span> <span style=''>in</span> <span style=''>the</span> <span style=''>remote</span> <span style=''>sensing</span> <span style=''>field</span> <span style=''>Because</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>technological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictions</span> <span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>hyperspectral</span> <span style=''>sensors</span> <span style=''>has</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6028368794326242);'>resolution</span> <span style=''>On</span> <span style=''>the</span> <span style=''>other</span> <span style=''>hand</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>panchromatic</span> <span style=''>image</span> <span style=''>has</span> <span style=''>a</span> <span style=''>better</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.6028368794326242);'>resolution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Combining</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>together</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>scene</span> <span style=''>Spectral</span> <span style=''>unmixing</span> <span style=''>of</span> <span style=''>mixed</span> <span style=''>pixels</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>hyperspectral</span> <span style=''>images</span> <span style=''>results</span> <span style=''>in</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>signature</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>abundance</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>fractions</span> <span style=''>of</span> <span style=''>endmembers</span> <span style=''>but</span> <span style=''>gives</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>their</span> <span style=''>location</span> <span style=''>in</span> <span style=''>a</span> <span style=''>mixed</span> <span style=''>pixel</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>have</span> <span style=''>used</span> <span style=''>spectral</span> <span style=''>unmixing</span> <span style=''>results</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.304347826086956 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>the</span> <span style=''>Maximum</span> <span style=''>Expected</span> <span style=''>Value</span> <span style=''>An</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>(Nested)</span> <span style=''>Cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Validation</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Maximum</span> <span style=''>Sample</span> <span style=''>Average</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style=''>most</span> <span style=''>common</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>for</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>expected</span> <span style=''>value</span> <span style=''>of</span> <span style=''>a</span> <span style=''>general</span> <span style=''>set</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>sample</span> <span style=''>average</span> <span style=''>and</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>No</span> <span style=''>unbiased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>exists</span> <span style=''>and</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>non</span> <span style=''>trivial</span> <span style=''>to</span> <span style=''>select</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>and</span> <span style=''>bound</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>and</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aforementioned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimators</span> <span style=''>and</span> <span style=''>prove</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>The</span> <span style=''>variance</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduced</span> <span style=''>but</span> <span style=''>not</span> <span style=''>without</span> <span style=''>risking</span> <span style=''>a</span> <span style=''>large</span> <span style=''>bias</span> <span style=''>The</span> <span style=''>bias</span> <span style=''>and</span> <span style=''>variance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Quantifying</span> <span style=''>the</span> <span style=''>probable</span> <span style='background-color:rgba(255, 0, 0, 0.35191637630662015);'>approximation</span> <span style=''>error</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3101160862354892);'>inference</span> <span style=''>programs</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.35191637630662015);'>approximation</span> <span style=''>error</span> <span style=''>of</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3101160862354892);'>inference</span> <span style=''>programs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>ones</span> <span style=''>based</span> <span style=''>on</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.6126482213438735);'>variational</span> <span style=''>and</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>derive</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.894736842105263);'>subjective</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>symmetrized</span> <span style=''>KL</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divergence</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857144);'>distribution</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style='background-color:rgba(255, 0, 0, 0.3101160862354892);'>inference</span> <span style=''>program</span> <span style=''>and</span> <span style=''>its</span> <span style=''>true</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857144);'>distribution</span> <span style=''>The</span> <span style=''>bounds</span> <span style=''>validity</span> <span style=''>(and</span> <span style=''>subjectivity)</span> <span style=''>rests</span> <span style=''>on</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>auxiliary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>programs</span> <span style=''>(i)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5068493150684932);'>reference</span> <span style='background-color:rgba(255, 0, 0, 0.3101160862354892);'>inference</span> <span style=''>program</span> <span style=''>that</span> <span style=''>defines</span> <span style=''>a</span> <span style=''>gold</span> <span style=''>standard</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>and</span> <span style=''>(ii)</span> <span style=''>a</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3101160862354892);'>inference</span> <span style=''>program</span> <span style=''>that</span> <span style=''>answers</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Traitement</span> <span style=''>Des</span> <span style=''>Donnees</span> <span style=''>Manquantes</span> <span style=''>Au</span> <span style=''>Moyen</span> <span style=''>De</span> <span style=''>LAlgorithme</span> <span style=''>De</span> <span style=''>Kohonen</span> <br/><br/><span style=''>Nous</span> <span style=''>montrons</span> <span style=''>comment</span> <span style=''>il</span> <span style=''>est</span> <span style=''>possible</span> <span style=''>dutiliser</span> <span style=''>lalgorithme</span> <span style=''>dauto</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>organisation</span> <span style=''>de</span> <span style=''>Kohonen</span> <span style=''>pour</span> <span style=''>traiter</span> <span style=''>des</span> <span style=''>donnees</span> <span style=''>avec</span> <span style=''>valeurs</span> <span style=''>manquantes</span> <span style=''>et</span> <span style=''>estimer</span> <span style=''>ces</span> <span style=''>dernieres</span> <span style=''>Apres</span> <span style=''>un</span> <span style=''>rappel</span> <span style=''>methodologique</span> <span style=''>nous</span> <span style=''>illustrons</span> <span style=''>notre</span> <span style=''>propos</span> <span style=''>a</span> <span style=''>partir</span> <span style=''>de</span> <span style=''>trois</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>a</span> <span style=''>des</span> <span style=''>donnees</span> <span style=''>reelles</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style=''>Kohonen</span> <span style=''>self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>data</span> <span style=''>which</span> <span style=''>contain</span> <span style=''>missing</span> <span style=''>values</span> <span style=''>and</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>them</span> <span style=''>After</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodological</span> <span style=''>recall</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>our</span> <span style=''>purpose</span> <span style=''>from</span> <span style=''>three</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13600288600288601)
# 	reasoning (0.05808080808080808)
# 	information (0.2536075036075036)
# 	knowledge (0.13672438672438672)
# 	representation (0.1341991341991342)
# 	segmentation (0.07828282828282829)
# 	detection (0.12806637806637808)
# 	recognition (0.1323953823953824)
# 	different (0.2730880230880231)
# 	convolutional (0.13816738816738816)
#
# Some Statistics words are:
# 	theoretical (0.14743589743589744)
# 	stochastic (0.13313609467455623)
# 	estimation (0.16074950690335305)
# 	variables (0.14250493096646943)
# 	statistical (0.15532544378698224)
# 	distribution (0.1814595660749507)
# 	algorithm (0.39349112426035504)
# 	dimensional (0.18293885601577908)
# 	inference (0.1947731755424063)
# 	regression (0.1794871794871795)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="878f69aa-a9ef-498f-aa23-d34e67ddab57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("878f69aa-a9ef-498f-aa23-d34e67ddab57")) {                    Plotly.newPlot(                        "878f69aa-a9ef-498f-aa23-d34e67ddab57",                        [{"x":["conventional","inconsistent","observations","quantitative","validation","extension","monitored","qualitative","monitoring","techniques","restricted","environment","impossible","connection","intermittent","instances","combination","persistent","partially","explanation","analogous","trajectory","successive","incorrect","interactions","reconstruction","simultaneously","explained","simulated","interacting","unsupervised","prevalent","represents","experiments","components","inference","dynamical","interplay","structure","accurately","underlying","constituent","relational","observational","interaction","interpretable","demonstrate","variational","introduce","estimates","nonparametric","estimated","estimation","stochastic","described","manuscript","nonlinear","distribution","constructed","accordingly","jackknife","uncertainty","estimator","statistical","assumptions","measurement","knowledge","uncertainties","construct","collisions","experience","reinforcement","properties","exploration","simulation","manipulation","suboptimal","heuristic","potential","precisely","explicitly","performance","empirical","theoretic","approximation","interdependent","collection","computational","summation","information","extensive","selection","technique","entropies","selections","maximizes","complexity","maximizing","approaches","comprehension","combinations","prediction","producing","automating","successes","suggested","correlation","manifestations","supervised","dependence","supervision","representations","translated","characterized","principle","redundancy","ambiguous","multivariate","including","converges","strategies","classifiers","convergence","differentiable","quadrature","expectation","algorithm","deterministic","combining","propagation","numerical","implicitly","computationally","substantially","inefficient","directions","hyperparameter","algorithms","available","practical","computation","inception","successfully","additional","resources","effectiveness","furthermore","diminishing","optimizer","alternatively","optimization","baselines","processes","graphical","preferable","previously","marginalization","applicable","precision","independent","attracted","approximations","rejection","continuous","intuitive","literature","combinatorics","approximate","comparably","determinantal","evaluation","relevance","important","generalized","revisited","undecidable","sensitive","constraint","languages","definition","simplifying","processed","condition","foundation","transducer","generative","phonology","extensions","derivations","hypotheses","equivalent","implemented","investigations","connections","sequential","nonmonotonic","populations","clustering","interested","individuals","according","separating","partition","partitioning","approximately","application","distributions","motivated","divergence","individual","population","correctly","inherently","component","industrial","diagnosis","benchmark","introduced","principal","erroneous","automatic","scalability","applicability","debugging","considering","responsible","classification","guarantees","framework","fundamental","mathematical","behaviors","developments","quantification","unlabeled","controllable","approximators","predictions","interpretability","answering","adversarial","universal","applications","recognition","regarding","solutions","perceptual","theoretical","stability","perspectives","tremendous","reliability","providing","generalization", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	jackknife
# 	rewritten
# 	disaggregate
# 	subroutines
# 	homogeneity
# 	noticeably
# 	idealized
# 	quadratures
# 	obscuring
# 	waveforms
# 	noninformative
# 	econometrics
# 	equitability
# 	equitable
# 	horizontally
# 	contamination
# 	semiparametric
# 	refitting
# 	penalization
# 	exposition
# Some words which never appear in Statistics papers:
# 	collisions
# 	undecidable
# 	transducer
# 	phonology
# 	nonmonotonic
# 	erroneous
# 	vehicular
# 	diffeomorphic
# 	registrations
# 	convincing
# 	portability
# 	revisions
# 	argumentative
# 	transcribes
# 	connectionist
# 	corrective
# 	intentions
# 	instructive
# 	committed
# 	attentive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.094059405940594e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333
